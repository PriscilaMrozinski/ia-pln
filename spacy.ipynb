# %% [markdown]
# <a href="https://colab.research.google.com/github/PriscilaMrozinski/ia-pln/blob/main/spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# spaCy é uma biblioteca de Processamento de Linguagem Natural (PLN) em Python

# %% [markdown]
# Algumas tarefas que realiza:
#
# -- Tokenização: dividir o texto em palavras ou frases.
#
# -- Lematização: reduzir palavras à sua forma base (ex: “correndo” → “correr”).
#
# -- Part-of-speech tagging (POS tagging): identificar a classe gramatical de cada palavra (substantivo, verbo etc.).
#
# -- Named Entity Recognition (NER): reconhecer entidades como nomes de pessoas, locais, empresas, datas, etc.
#
# -- Parsing: analisar a estrutura sintática de uma frase.
#
# -- Vetorização semântica: transformar texto em vetores numéricos para uso em modelos de IA.

# %%
# !pip install -U Spacy==3.8.7
# Out:
# Requirement already satisfied: Spacy==3.8.7 in /usr/local/lib/python3.12/dist-packages (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from Spacy==3.8.7) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from Spacy==3.8.7) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from Spacy==3.8.7) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from Spacy==3.8.7) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from Spacy==3.8.7) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from Spacy==3.8.7) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from Spacy==3.8.7) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from Spacy==3.8.7) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from Spacy==3.8.7) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from Spacy==3.8.7) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from Spacy==3.8.7) (0.20.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from Spacy==3.8.7) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from Spacy==3.8.7) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from Spacy==3.8.7) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from Spacy==3.8.7) (2.11.10)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from Spacy==3.8.7) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from Spacy==3.8.7) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from Spacy==3.8.7) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from Spacy==3.8.7) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.12/dist-packages (from langcodes<4.0.0,>=3.2.0->Spacy==3.8.7) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->Spacy==3.8.7) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->Spacy==3.8.7) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->Spacy==3.8.7) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->Spacy==3.8.7) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->Spacy==3.8.7) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->Spacy==3.8.7) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->Spacy==3.8.7) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->Spacy==3.8.7) (2025.10.5)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->Spacy==3.8.7) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->Spacy==3.8.7) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->Spacy==3.8.7) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->Spacy==3.8.7) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->Spacy==3.8.7) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.1.0->Spacy==3.8.7) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.1.0->Spacy==3.8.7) (7.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->Spacy==3.8.7) (3.0.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->Spacy==3.8.7) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->Spacy==3.8.7) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->Spacy==3.8.7) (2.19.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->Spacy==3.8.7) (2.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->Spacy==3.8.7) (0.1.2)

# %% [markdown]
# Baixar Modelo de Treinamento

# %%
import spacy
print(spacy.__version__)

# !python -m spacy download 'pt_core_news_lg'
print("Lib carregada")
# Out:
# 3.8.7
# Collecting pt-core-news-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_lg-3.8.0/pt_core_news_lg-3.8.0-py3-none-any.whl (568.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.2/568.2 MB 3.2 MB/s eta 0:00:00
# Installing collected packages: pt-core-news-lg
# Successfully installed pt-core-news-lg-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Lib carregada

# %%
nlp = spacy.load("pt_core_news_lg")

# %%
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'morphologizer', 'parser', 'lemmatizer', 'attribute_ruler', 'ner']

# %%
documento = nlp("Os alunos do 6º módulo da Fatec os 100% presentes aqui chegarão ao fim de uma jornada que começou com sonhos, dúvidas, expectativas e desafios. E, ao olhar para trás e hoje, cada esforço, cada noite estudando, cada projeto entregue e cada obstáculo superado formam a base sólida que formarão vocês")

# %%
##documento = nlp("A segurança de banco de dados pode ser entendida como a proteção dos dados contra acesso não autorizado e uso indevido, baseada em trê pilares: confidencialidade, integridade e disponibilidade. www.ibm.com.br/security")

# %% [markdown]
# Contar o texto:

# %%
len(documento.vocab)
# Out:
# 417

# %% [markdown]
# Verificar tipo de documento

# %%
print(type(documento))
# Out:
# <class 'spacy.tokens.doc.Doc'>

# %% [markdown]
# TexTos são codificados em hashes únicos

# %% [markdown]
# --- Token ---

# %%
for token in documento: print(token.text)
# Out:
# A
# segurança
# de
# banco
# de
# dados
# pode
# ser
# entendida
# como
# a
# proteção
# dos
# dados
# contra
# acesso
# não
# autorizado
# e
# uso
# indevido
# ,
# baseada
# em
# trê
# pilares
# :
# confidencialidade
# ,
# integridade
# e
# disponibilidade
# .
# www.ibm.com.br/security

# %%
## Buscar a palavra na posição 3 (Atenção! Começa posição zero)
print(documento[3])
# Out:
# banco

# %%
## Printar a posição 3 a 6
print(documento[3:6])
# Out:
# banco de dados

# %%
## Busca a posição 33
print(documento[33])
# Out:
# www.ibm.com.br/security

# %%
##Conta quantas palavras tem o documento
print(len(documento))
# Out:
# 34

# %%
##Verificar os Atributos
print("Tokens:", [token.text for token in documento])
# Out:
# Tokens: ['A', 'segurança', 'de', 'banco', 'de', 'dados', 'pode', 'ser', 'entendida', 'como', 'a', 'proteção', 'dos', 'dados', 'contra', 'acesso', 'não', 'autorizado', 'e', 'uso', 'indevido', ',', 'baseada', 'em', 'trê', 'pilares', ':', 'confidencialidade', ',', 'integridade', 'e', 'disponibilidade', '.', 'www.ibm.com.br/security']

# %%
## Verifica se o elemento é ou não uma palavra, segurança é true, virgula é false
print("Stop Word:", [token.is_stop for token in documento])
# Out:
# Stop Word: [True, False, True, False, True, False, True, True, False, True, True, False, True, False, True, False, True, False, True, False, False, False, False, True, False, False, False, False, False, False, True, False, False, False]

# %%
print("Alfanumérico:", [token.is_alpha for token in documento])
# Out:
# Alfanumérico: [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, False, True, False, True, True, True, False, False]

# %%
print("Maíusculo:", [token.is_upper for token in documento])
# Out:
# Maíusculo: [True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]

# %%
print("Pontuação:", [token.like_num for token in documento])
# Out:
# Pontuação: [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]

# %%
print("Sentença inicial:", [token.is_sent_start for token in documento])
# Out:
# Sentença inicial: [True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True]

# %%
print("Tokens:", [token.text for token in documento])
print("Stop Word:", [token.is_stop for token in documento])
print("Alfanumérico:", [token.is_alpha for token in documento])
print("Maíusculo:", [token.is_upper for token in documento])
print("Pontuação:", [token.like_num for token in documento])
print("Sentença inicial:", [token.is_sent_start for token in documento])
# Out:
# Tokens: ['A', 'segurança', 'de', 'banco', 'de', 'dados', 'pode', 'ser', 'entendida', 'como', 'a', 'proteção', 'dos', 'dados', 'contra', 'acesso', 'não', 'autorizado', 'e', 'uso', 'indevido', ',', 'baseada', 'em', 'trê', 'pilares', ':', 'confidencialidade', ',', 'integridade', 'e', 'disponibilidade', '.', 'www.ibm.com.br/security']
# Stop Word: [True, False, True, False, True, False, True, True, False, True, True, False, True, False, True, False, True, False, True, False, False, False, False, True, False, False, False, False, False, False, True, False, False, False]
# Alfanumérico: [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, False, True, False, True, True, True, False, False]
# Maíusculo: [True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]
# Pontuação: [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]
# Sentença inicial: [True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True]

# %%
print("=== Tokens e Partes do Discurso ===")
for token in documento:
    print(f"{token.text:<15} | {token.pos_:<10} | {token.dep_:<10}")

print("\n=== Entidades Nomeadas (NER) ===")
for ent in documento.ents:
    print(f"{ent.text:<30} -> {ent.label_}")
# Out:
# === Tokens e Partes do Discurso ===
# A               | DET        | det
# segurança       | NOUN       | nsubj:pass
# de              | ADP        | case
# banco           | NOUN       | nmod
# de              | ADP        | case
# dados           | NOUN       | nmod
# pode            | VERB       | ROOT
# ser             | AUX        | aux:pass
# entendida       | VERB       | xcomp
# como            | ADP        | case
# a               | DET        | det
# proteção        | NOUN       | xcomp
# dos             | ADP        | case
# dados           | NOUN       | nmod
# contra          | ADP        | case
# acesso          | NOUN       | nmod
# não             | ADV        | advmod
# autorizado      | VERB       | acl
# e               | CCONJ      | cc
# uso             | NOUN       | conj
# indevido        | ADJ        | amod
# ,               | PUNCT      | punct
# baseada         | VERB       | acl
# em              | ADP        | case
# trê             | NOUN       | obl
# pilares         | NOUN       | amod
# :               | PUNCT      | punct
# confidencialidade | NOUN       | appos
# ,               | PUNCT      | punct
# integridade     | NOUN       | conj
# e               | CCONJ      | cc
# disponibilidade | NOUN       | conj
# .               | PUNCT      | punct
# www.ibm.com.br/security | NOUN       | ROOT
#
# === Entidades Nomeadas (NER) ===
# trê                            -> MISC

# %%
import re

texto = "A segurança de banco de dados pode ser entendida como a proteção dos dados contra acesso não autorizado e uso indevido, baseada em três pilares: confidencialidade, integridade e disponibilidade. www.ibm.com.br/security"

urls = re.findall(r'(https?://[^\s]+|www\.[^\s]+)', texto)

print("URLs encontradas:", urls)
# Out:
# URLs encontradas: ['www.ibm.com.br/security']

# %%
print("Tokens:", [token.text for token in documento])
print("POS:", [token.pos_ for token in documento])
print("Formato:", [token.shape_ for token in documento])
# Out:
# Tokens: ['A', 'segurança', 'de', 'banco', 'de', 'dados', 'pode', 'ser', 'entendida', 'como', 'a', 'proteção', 'dos', 'dados', 'contra', 'acesso', 'não', 'autorizado', 'e', 'uso', 'indevido', ',', 'baseada', 'em', 'trê', 'pilares', ':', 'confidencialidade', ',', 'integridade', 'e', 'disponibilidade', '.', 'www.ibm.com.br/security']
# POS: ['DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', 'VERB', 'AUX', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', 'ADV', 'VERB', 'CCONJ', 'NOUN', 'ADJ', 'PUNCT', 'VERB', 'ADP', 'NOUN', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN', 'CCONJ', 'NOUN', 'PUNCT', 'NOUN']
# Formato: ['X', 'xxxx', 'xx', 'xxxx', 'xx', 'xxxx', 'xxxx', 'xxx', 'xxxx', 'xxxx', 'x', 'xxxx', 'xxx', 'xxxx', 'xxxx', 'xxxx', 'xxx', 'xxxx', 'x', 'xxx', 'xxxx', ',', 'xxxx', 'xx', 'xxx', 'xxxx', ':', 'xxxx', ',', 'xxxx', 'x', 'xxxx', '.', 'xxx.xxx.xxx.xx/xxxx']

# %%
for token in documento:
  if token.like_num:
    print("Número encontrado: ", token.text)
    if token.is_punct:
      print("Pontuação encontrada: ", token.text)
# Out:
# Número encontrado:  6º
# Número encontrado:  100
